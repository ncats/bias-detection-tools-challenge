# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanpoo/mlkfairness/blob/main/MLKFairness_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import sys
sys.path.append('/content/gdrive/MyDrive/mypython')

# %%
import argparse
from argparse import RawTextHelpFormatter

import pandas as pd

from mlkfairness.detector import BiasDetector
from mlkfairness.data import Dataset, load_hmda, get_random_dataset

# %%
ds = get_random_dataset()

print(ds.df.info())
adetector = BiasDetector(ds)
ret = adetector.generate_report()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   y       100 non-null    int64
#  1   y_hat   100 non-null    int64
#  2   Black   100 non-null    int64
#  3   White   100 non-null    int64
# dtypes: int64(4)
# memory usage: 3.2 KB
# None
# *** Full bias detection report for [random_dataset] dataset ***
# 2023-03-02 02:29
# *legend for method ratios: ???
#
# Pairwise bias detection results for Black vs White in group Race
# 	Equalized Odds: naTP(A=1)/naTP(A=0)+ naFP(A=1)/naFP(A=0)=2.39, pvalue=0.39
# 	Equal Opportunity: naTP(A=1)/naTP(A=0)=0.94, pvalue=1.00
# 	See the plot of Equalized Odds.
#
# 	Demographic Parity: nP(A=1)/nP(A=0)=1.00, pvalue=0.75
# 	Calibration Fairness*: npTP(A=1)/npTP(A=0) + npFN(A=1)/npFN(A=0)=2.00, pvalue=0.05
# 	Differential Validity*: ndTP(A=1)/ndTP(A=0)=1.08, pvalue=0.00
